# %%
import itertools
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import numpy_groupies as npg
import pandas as pd
import scipy.stats as s
import scipy.special as ss
import sortedcontainers as sc
import os
import tqdm
import matplotlib

# %%
os.environ["CAPY_REF_FA"] = "/home/opriebe/data/ref/hg19/Homo_sapiens_assembly19.fasta"
import hapaseg.coverage_MCMC as mcmc_cov
import hapaseg.NB_coverage_MCMC as nb_cov
from capy import mut, seq
# Out:
# Cannot find path to gnomAD index; gnomAD functionality disabled.

# %% [markdown]
# Load MCMC trace over SNP DP cluster assignments. Still looking at only the high purity exome

# %%
colors = mpl.cm.get_cmap("tab10").colors

# %% [markdown]
# ### Load coverage

# %%
Cov = pd.read_csv("exome/6_C1D1_META.cov", sep = "\t", names = ["chr", "start", "end", "covcorr", "covraw"], low_memory=False)
Cov["chr"] = mut.convert_chr(Cov["chr"])
Cov = Cov.loc[Cov["chr"] != 0]
Cov["start_g"] = seq.chrpos2gpos(Cov["chr"], Cov["start"])
Cov["end_g"] = seq.chrpos2gpos(Cov["chr"], Cov["end"])

# %% [markdown]
# ### Load covariates

# %%
Cov["C_len"] = Cov["end"] - Cov["start"] + 1

# load repl timing
F = pd.read_pickle("covars/GSE137764_H1.hg19_liftover.pickle")

# map targets to RT intervals
tidx = mut.map_mutations_to_targets(Cov.rename(columns = { "start" : "pos" }), F, inplace = False)
Cov.loc[tidx.index, "C_RT"] = F.iloc[tidx, 3:].mean(1).values

# z-transform
Cov["C_RT_z"] = (lambda x : (x - np.nanmean(x))/np.nanstd(x))(np.log(Cov["C_RT"] + 1e-20))

#load GC content
B = pd.read_pickle("covars/GC.pickle")
Cov = Cov.merge(B.rename(columns = { "gc" : "C_GC" }), left_on = ["chr", "start", "end"], right_on = ["chr", "start", "end"], how = "left")
Cov["C_GC_z"] = (lambda x : (x - np.nanmean(x))/np.nanstd(x))(np.log(Cov["C_GC"] + 1e-20))

# %%
clust = np.load("exome/6_C1D1_META.DP_clusts.auto_ref_correct.overdispersion92.no_phase_correct.npz")

# %% [markdown]
# #### Load chromosome boundary coordinates

# %%
allelic_segs = pd.read_pickle("exome/6_C1D1_META.allelic_segs.auto_ref_correct.overdispersion92.no_phase_correct.pickle")
chrbdy = allelic_segs.dropna().loc[:, ["start", "end"]]
chr_ends = chrbdy.loc[chrbdy["start"] != 0, "end"].cumsum()

# %%
clust["snps_to_clusters"].shape
# Out:
# (500, 11768)

# %%
SNPs = pd.read_pickle("exome/6_C1D1_META.SNPs.pickle")
SNPs["chr"], SNPs["pos"] = seq.gpos2chrpos(SNPs["gpos"])

SNPs["tidx"] = mut.map_mutations_to_targets(SNPs, Cov, inplace = False)

#generate unique clust assignments
clust_u, clust_uj = np.unique(clust["snps_to_clusters"], return_inverse = True)
clust_uj = clust_uj.reshape(clust["snps_to_clusters"].shape)

# %% [markdown]
# ### load SNPs from single DP iteration

# %%
iter_ind = 499
SNPs = pd.read_pickle("exome/6_C1D1_META.SNPs.pickle")
SNPs["chr"], SNPs["pos"] = seq.gpos2chrpos(SNPs["gpos"])

SNPs["tidx"] = mut.map_mutations_to_targets(SNPs, Cov, inplace = False)

#generate unique clust assignments
clust_u, clust_uj = np.unique(clust["snps_to_clusters"], return_inverse = True)
clust_uj = clust_uj.reshape(clust["snps_to_clusters"].shape)

#assign coverage intervals to clusters
Cov_clust_probs = np.zeros([len(Cov), clust_u.max()])

for targ, snp_idx in SNPs.groupby("tidx").indices.items():
    targ_clust_hist = np.bincount(clust_uj[499, snp_idx].ravel(), minlength = clust_u.max())

    Cov_clust_probs[int(targ), :] = targ_clust_hist/targ_clust_hist.sum()

#subset intervals containing SNPs
overlap_idx = Cov_clust_probs.sum(1) > 0
Cov_clust_probs_overlap = Cov_clust_probs[overlap_idx, :]

#prune improbable assignments
Cov_clust_probs_overlap[Cov_clust_probs_overlap < 0.05] = 0
Cov_clust_probs_overlap /= Cov_clust_probs_overlap.sum(1)[:, None]
prune_idx = Cov_clust_probs_overlap.sum(0) > 0
Cov_clust_probs_overlap = Cov_clust_probs_overlap[:, prune_idx]

# %%
import scipy.stats
assgn_entropy = scipy.stats.entropy(Cov_clust_probs_overlap, axis=1)
entropy_idx = (assgn_entropy == 0)

#subsetting to only targets that overlap SNPs
Cov_overlap = Cov.loc[overlap_idx, :]

#subsetting to only targets with hard assignments
Cov_overlap = Cov_overlap.loc[entropy_idx,:]

r = np.c_[Cov_overlap["covcorr"]]

#making covariate matrix
C = np.c_[np.log(Cov_overlap["C_len"]), Cov_overlap["C_RT_z"], Cov_overlap["C_GC_z"]]

Pi = Cov_clust_probs_overlap[entropy_idx,:].copy()

#dropping Nans
naidx = np.isnan(C[:, 1])
r = r[~naidx]
C = C[~naidx]
Pi = Pi[~naidx]

Cov_overlap = Cov_overlap.iloc[~naidx]

mu = np.log(r.mean()*np.ones([Pi.shape[1], 1])) / 2
beta = np.ones([C.shape[1], 1])
mu_i = np.zeros(C.shape[0])
epsi = np.ones((mu.shape)) *2

Cov_overlap['cluster_assgn'] = np.argmax(Pi, axis=1)

# %% [markdown]
# almost all bins are unanimously assigned

# %%
#subsetting to only targets that overlap SNPs
Cov_overlap = Cov.loc[overlap_idx, :]

#subsetting to only targets with hard assignments
Cov_overlap = Cov_overlap.loc[entropy_idx,:]

r = np.c_[Cov_overlap["covcorr"]]

#making covariate matrix
C = np.c_[np.log(Cov_overlap["C_len"]), Cov_overlap["C_RT_z"], Cov_overlap["C_GC_z"]]

Pi = Cov_clust_probs_overlap[entropy_idx,:].copy()

# %%
#dropping Nans
naidx = np.isnan(C[:, 1])
r = r[~naidx]
C = C[~naidx]
Pi = Pi[~naidx]

# %%
Cov_overlap = Cov_overlap.iloc[~naidx]

# %%
mu = np.log(r.mean()*np.ones([Pi.shape[1], 1])) / 2
beta = np.ones([C.shape[1], 1])
mu_i = np.zeros(C.shape[0])
epsi = np.ones((mu.shape)) *2

# %%
Cov_overlap['cluster_assgn'] = np.argmax(Pi, axis=1)

# %%
nb_mcmc = nb_cov.NB_MCMC(r, C, Pi)

# %%
nb_mcmc.run()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# starting MCMC coverage segmentation...
#   0%|          | 3/10000 [00:12<12:53:57,  4.65s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   0%|          | 36/10000 [01:03<4:35:46,  1.66s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   0%|          | 39/10000 [01:09<5:20:31,  1.93s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   1%|          | 62/10000 [01:39<3:34:56,  1.30s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   1%|▏         | 142/10000 [04:11<2:46:22,  1.01s/it] /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 156/10000 [04:24<3:01:54,  1.11s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 158/10000 [04:25<2:29:24,  1.10it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 163/10000 [04:27<1:38:01,  1.67it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 175/10000 [05:01<5:38:38,  2.07s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 193/10000 [05:26<3:55:56,  1.44s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 194/10000 [05:30<5:50:45,  2.15s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 226/10000 [06:04<2:24:20,  1.13it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   2%|▏         | 228/10000 [06:04<1:40:21,  1.62it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 252/10000 [06:27<3:25:33,  1.27s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 262/10000 [06:32<1:46:37,  1.52it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 276/10000 [06:41<56:45,  2.86it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 279/10000 [06:43<1:21:53,  1.98it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 281/10000 [06:48<3:01:04,  1.12s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 302/10000 [07:09<2:45:29,  1.02s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 307/10000 [07:11<1:15:15,  2.15it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 325/10000 [07:28<2:28:42,  1.08it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 327/10000 [07:29<1:29:50,  1.79it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   3%|▎         | 331/10000 [07:35<3:14:30,  1.21s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   4%|▎         | 351/10000 [07:56<1:44:08,  1.54it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   4%|▎         | 355/10000 [07:57<1:16:12,  2.11it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   4%|▎         | 366/10000 [08:07<2:58:52,  1.11s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   4%|▍         | 395/10000 [08:25<52:02,  3.08it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   4%|▍         | 405/10000 [08:31<1:26:53,  1.84it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▍         | 451/10000 [09:03<2:15:14,  1.18it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▍         | 454/10000 [09:04<1:09:59,  2.27it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▍         | 471/10000 [09:10<1:06:43,  2.38it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▍         | 482/10000 [09:14<1:08:09,  2.33it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▍         | 488/10000 [09:16<46:19,  3.42it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▌         | 528/10000 [09:52<1:31:25,  1.73it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   5%|▌         | 535/10000 [09:53<44:41,  3.53it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   6%|▌         | 558/10000 [10:14<1:09:32,  2.26it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   6%|▌         | 597/10000 [10:52<2:21:27,  1.11it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   6%|▌         | 616/10000 [11:02<2:01:10,  1.29it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   6%|▋         | 635/10000 [11:10<1:05:04,  2.40it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   8%|▊         | 780/10000 [12:25<1:53:00,  1.36it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   8%|▊         | 798/10000 [12:33<1:15:39,  2.03it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   8%|▊         | 813/10000 [12:47<2:03:47,  1.24it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   8%|▊         | 818/10000 [12:54<3:07:15,  1.22s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#   9%|▉         | 936/10000 [14:14<57:11,  2.64it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  10%|▉         | 954/10000 [14:25<1:30:04,  1.67it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  10%|▉         | 959/10000 [14:28<1:28:46,  1.70it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  10%|█         | 1016/10000 [15:12<1:02:31,  2.40it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  10%|█         | 1026/10000 [15:16<56:33,  2.64it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  12%|█▏        | 1210/10000 [17:25<2:03:06,  1.19it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  12%|█▏        | 1227/10000 [17:43<2:24:44,  1.01it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  12%|█▏        | 1237/10000 [17:52<2:06:51,  1.15it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  13%|█▎        | 1325/10000 [18:52<52:40,  2.75it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  14%|█▍        | 1444/10000 [20:17<56:52,  2.51it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  15%|█▍        | 1454/10000 [20:20<44:13,  3.22it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  16%|█▌        | 1552/10000 [21:21<1:48:15,  1.30it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  16%|█▌        | 1561/10000 [21:27<1:08:26,  2.06it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  16%|█▌        | 1611/10000 [22:03<1:02:49,  2.23it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  16%|█▌        | 1620/10000 [22:10<1:43:38,  1.35it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  16%|█▋        | 1637/10000 [22:19<1:03:11,  2.21it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  17%|█▋        | 1657/10000 [22:36<2:58:58,  1.29s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  17%|█▋        | 1664/10000 [22:38<1:05:36,  2.12it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  17%|█▋        | 1687/10000 [22:57<38:17,  3.62it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  17%|█▋        | 1708/10000 [23:07<1:22:21,  1.68it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  17%|█▋        | 1717/10000 [23:12<2:05:12,  1.10it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  19%|█▊        | 1857/10000 [24:27<45:18,  3.00it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  19%|█▉        | 1892/10000 [24:58<1:22:52,  1.63it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  19%|█▉        | 1913/10000 [25:05<24:49,  5.43it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  19%|█▉        | 1942/10000 [25:17<1:25:09,  1.58it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  20%|█▉        | 1995/10000 [25:47<37:34,  3.55it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  20%|██        | 2014/10000 [25:55<38:36,  3.45it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  20%|██        | 2049/10000 [26:12<37:32,  3.53it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  21%|██        | 2053/10000 [26:13<32:50,  4.03it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  21%|██        | 2099/10000 [26:37<46:20,  2.84it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  21%|██        | 2123/10000 [26:50<2:01:35,  1.08it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  22%|██▏       | 2178/10000 [27:10<1:07:48,  1.92it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  22%|██▏       | 2182/10000 [27:12<55:29,  2.35it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  22%|██▏       | 2238/10000 [27:39<30:04,  4.30it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  22%|██▏       | 2244/10000 [27:40<34:15,  3.77it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  23%|██▎       | 2253/10000 [27:55<3:23:21,  1.58s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  23%|██▎       | 2266/10000 [28:01<55:05,  2.34it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  23%|██▎       | 2267/10000 [28:01<53:28,  2.41it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  23%|██▎       | 2297/10000 [28:18<48:02,  2.67it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  23%|██▎       | 2340/10000 [28:35<44:11,  2.89it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  23%|██▎       | 2348/10000 [28:38<39:18,  3.24it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  24%|██▎       | 2370/10000 [28:51<1:26:59,  1.46it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  24%|██▍       | 2379/10000 [28:54<36:04,  3.52it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  24%|██▍       | 2396/10000 [29:03<46:47,  2.71it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  24%|██▍       | 2406/10000 [29:06<46:57,  2.70it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  24%|██▍       | 2438/10000 [29:26<1:18:14,  1.61it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  25%|██▍       | 2463/10000 [29:39<47:09,  2.66it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  25%|██▍       | 2466/10000 [29:39<38:17,  3.28it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  25%|██▍       | 2473/10000 [29:41<36:21,  3.45it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  25%|██▌       | 2503/10000 [30:04<1:38:46,  1.26it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  25%|██▌       | 2508/10000 [30:07<1:05:26,  1.91it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  25%|██▌       | 2517/10000 [30:10<54:09,  2.30it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  26%|██▌       | 2600/10000 [30:58<52:26,  2.35it/s]
# burnt in!
#  26%|██▋       | 2626/10000 [31:12<1:12:36,  1.69it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  27%|██▋       | 2707/10000 [31:54<52:27,  2.32it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  27%|██▋       | 2740/10000 [32:21<2:46:21,  1.37s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  28%|██▊       | 2814/10000 [33:00<31:54,  3.75it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  28%|██▊       | 2840/10000 [33:18<2:03:31,  1.04s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  28%|██▊       | 2847/10000 [33:20<39:45,  3.00it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  29%|██▉       | 2931/10000 [34:28<1:39:53,  1.18it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  29%|██▉       | 2946/10000 [34:35<39:17,  2.99it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  29%|██▉       | 2948/10000 [34:45<6:25:47,  3.28s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  30%|██▉       | 2951/10000 [34:46<3:05:05,  1.58s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  30%|███       | 3000/10000 [35:12<1:21:33,  1.43it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  32%|███▏      | 3203/10000 [37:07<44:05,  2.57it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  33%|███▎      | 3317/10000 [38:20<1:14:39,  1.49it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  34%|███▎      | 3370/10000 [38:59<48:19,  2.29it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  34%|███▍      | 3391/10000 [39:09<52:31,  2.10it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  36%|███▌      | 3554/10000 [40:27<49:26,  2.17it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  37%|███▋      | 3738/10000 [42:14<22:39,  4.61it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  38%|███▊      | 3757/10000 [42:29<54:04,  1.92it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  38%|███▊      | 3771/10000 [42:44<1:19:25,  1.31it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  38%|███▊      | 3789/10000 [42:51<31:38,  3.27it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  38%|███▊      | 3800/10000 [42:55<26:57,  3.83it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  39%|███▉      | 3934/10000 [44:19<39:05,  2.59it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  40%|███▉      | 3978/10000 [44:41<41:58,  2.39it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  41%|████      | 4077/10000 [45:32<31:52,  3.10it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  41%|████      | 4122/10000 [46:01<28:33,  3.43it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  41%|████▏     | 4128/10000 [46:06<1:07:11,  1.46it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  41%|████▏     | 4130/10000 [46:07<1:06:51,  1.46it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  42%|████▏     | 4178/10000 [46:34<48:33,  2.00it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  42%|████▏     | 4213/10000 [46:46<50:30,  1.91it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  43%|████▎     | 4255/10000 [47:06<57:59,  1.65it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  43%|████▎     | 4299/10000 [47:26<56:55,  1.67it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  44%|████▍     | 4406/10000 [48:28<1:03:44,  1.46it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  45%|████▍     | 4454/10000 [49:06<41:15,  2.24it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  45%|████▌     | 4501/10000 [49:26<52:08,  1.76it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  45%|████▌     | 4516/10000 [49:32<52:37,  1.74it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  45%|████▌     | 4520/10000 [49:34<50:01,  1.83it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  46%|████▌     | 4558/10000 [49:49<24:26,  3.71it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  46%|████▌     | 4598/10000 [50:06<22:09,  4.06it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  46%|████▋     | 4650/10000 [50:31<35:20,  2.52it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  47%|████▋     | 4727/10000 [51:11<53:13,  1.65it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  48%|████▊     | 4833/10000 [52:06<1:16:51,  1.12it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  49%|████▊     | 4868/10000 [52:28<20:14,  4.23it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  49%|████▊     | 4872/10000 [52:29<26:50,  3.18it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  50%|████▉     | 4954/10000 [53:10<56:44,  1.48it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  50%|████▉     | 4978/10000 [53:21<39:29,  2.12it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  50%|█████     | 5001/10000 [53:29<47:40,  1.75it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  50%|█████     | 5049/10000 [53:48<18:25,  4.48it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  51%|█████     | 5097/10000 [54:18<36:08,  2.26it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  52%|█████▏    | 5232/10000 [55:59<1:14:09,  1.07it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  54%|█████▎    | 5356/10000 [57:06<18:40,  4.14it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  55%|█████▍    | 5461/10000 [58:00<25:34,  2.96it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  55%|█████▍    | 5489/10000 [58:15<33:01,  2.28it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  56%|█████▌    | 5556/10000 [59:00<45:00,  1.65it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  56%|█████▌    | 5584/10000 [59:18<32:04,  2.29it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  56%|█████▌    | 5610/10000 [59:26<35:44,  2.05it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  56%|█████▌    | 5623/10000 [59:31<28:17,  2.58it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  58%|█████▊    | 5751/10000 [1:00:46<26:39,  2.66it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  58%|█████▊    | 5830/10000 [1:01:36<1:18:01,  1.12s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  59%|█████▊    | 5859/10000 [1:01:58<53:17,  1.29it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  59%|█████▉    | 5891/10000 [1:02:11<14:42,  4.66it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  60%|█████▉    | 5960/10000 [1:02:47<40:34,  1.66it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  60%|██████    | 6010/10000 [1:03:23<25:43,  2.58it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  62%|██████▏   | 6178/10000 [1:05:33<17:42,  3.60it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  62%|██████▏   | 6205/10000 [1:05:48<27:00,  2.34it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  63%|██████▎   | 6251/10000 [1:06:12<16:35,  3.76it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  63%|██████▎   | 6265/10000 [1:06:21<37:53,  1.64it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  63%|██████▎   | 6284/10000 [1:06:33<34:48,  1.78it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  63%|██████▎   | 6302/10000 [1:06:43<43:23,  1.42it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  63%|██████▎   | 6330/10000 [1:06:58<19:28,  3.14it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  64%|██████▍   | 6423/10000 [1:07:48<15:42,  3.80it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  65%|██████▍   | 6491/10000 [1:08:27<18:52,  3.10it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  65%|██████▍   | 6496/10000 [1:08:33<34:42,  1.68it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  65%|██████▍   | 6499/10000 [1:08:34<27:37,  2.11it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  65%|██████▌   | 6541/10000 [1:08:56<29:33,  1.95it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  66%|██████▋   | 6627/10000 [1:09:40<21:22,  2.63it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  66%|██████▋   | 6631/10000 [1:09:41<15:27,  3.63it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  66%|██████▋   | 6640/10000 [1:09:45<31:12,  1.79it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  67%|██████▋   | 6656/10000 [1:09:59<42:59,  1.30it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  67%|██████▋   | 6674/10000 [1:10:06<28:32,  1.94it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  67%|██████▋   | 6686/10000 [1:10:11<22:02,  2.51it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  67%|██████▋   | 6695/10000 [1:10:17<47:05,  1.17it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  68%|██████▊   | 6754/10000 [1:10:56<32:15,  1.68it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  68%|██████▊   | 6806/10000 [1:11:48<14:07,  3.77it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  70%|██████▉   | 6974/10000 [1:13:29<16:04,  3.14it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  70%|██████▉   | 6981/10000 [1:13:31<18:16,  2.75it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  72%|███████▏  | 7180/10000 [1:15:31<18:48,  2.50it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  72%|███████▏  | 7209/10000 [1:15:54<1:26:16,  1.85s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  72%|███████▏  | 7215/10000 [1:15:58<46:56,  1.01s/it]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  72%|███████▏  | 7238/10000 [1:16:07<27:41,  1.66it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  72%|███████▎  | 7250/10000 [1:16:19<44:40,  1.03it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  73%|███████▎  | 7254/10000 [1:16:21<30:07,  1.52it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  73%|███████▎  | 7274/10000 [1:16:33<20:22,  2.23it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  73%|███████▎  | 7284/10000 [1:16:38<21:41,  2.09it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  73%|███████▎  | 7323/10000 [1:17:08<1:06:36,  1.49s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  74%|███████▍  | 7402/10000 [1:18:14<59:52,  1.38s/it]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  74%|███████▍  | 7404/10000 [1:18:15<45:34,  1.05s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  74%|███████▍  | 7437/10000 [1:18:32<31:51,  1.34it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  76%|███████▌  | 7551/10000 [1:19:27<14:17,  2.85it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  76%|███████▌  | 7594/10000 [1:19:59<17:23,  2.31it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  76%|███████▌  | 7619/10000 [1:20:12<16:51,  2.35it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  77%|███████▋  | 7661/10000 [1:20:33<23:06,  1.69it/s]  /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  78%|███████▊  | 7772/10000 [1:21:29<16:21,  2.27it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  78%|███████▊  | 7777/10000 [1:21:33<24:09,  1.53it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  78%|███████▊  | 7838/10000 [1:22:04<10:50,  3.32it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  79%|███████▊  | 7853/10000 [1:22:14<14:49,  2.41it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  80%|████████  | 8005/10000 [1:23:28<12:47,  2.60it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  80%|████████  | 8018/10000 [1:23:36<29:56,  1.10it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  81%|████████  | 8070/10000 [1:24:15<31:08,  1.03it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  82%|████████▏ | 8220/10000 [1:25:32<12:20,  2.40it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  83%|████████▎ | 8277/10000 [1:25:56<18:16,  1.57it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  83%|████████▎ | 8282/10000 [1:25:59<18:35,  1.54it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  83%|████████▎ | 8319/10000 [1:26:28<34:14,  1.22s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  84%|████████▎ | 8371/10000 [1:27:00<16:08,  1.68it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  84%|████████▍ | 8421/10000 [1:27:20<10:47,  2.44it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  85%|████████▌ | 8517/10000 [1:28:21<04:23,  5.63it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  86%|████████▌ | 8573/10000 [1:28:45<14:38,  1.62it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  86%|████████▌ | 8614/10000 [1:29:02<09:20,  2.47it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  86%|████████▋ | 8630/10000 [1:29:08<13:40,  1.67it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  86%|████████▋ | 8648/10000 [1:29:13<14:07,  1.60it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  87%|████████▋ | 8673/10000 [1:29:24<10:10,  2.17it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  87%|████████▋ | 8695/10000 [1:29:38<08:24,  2.59it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  88%|████████▊ | 8844/10000 [1:31:09<09:56,  1.94it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  91%|█████████ | 9059/10000 [1:33:06<10:34,  1.48it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  91%|█████████▏| 9141/10000 [1:33:47<08:49,  1.62it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  92%|█████████▏| 9226/10000 [1:34:40<03:07,  4.13it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  92%|█████████▏| 9227/10000 [1:34:40<02:42,  4.75it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  92%|█████████▏| 9232/10000 [1:34:41<02:15,  5.66it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  92%|█████████▏| 9236/10000 [1:34:42<03:14,  3.93it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  93%|█████████▎| 9265/10000 [1:35:00<10:48,  1.13it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  93%|█████████▎| 9268/10000 [1:35:01<06:05,  2.00it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  93%|█████████▎| 9273/10000 [1:35:05<09:50,  1.23it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  93%|█████████▎| 9290/10000 [1:35:15<05:01,  2.36it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  93%|█████████▎| 9313/10000 [1:35:31<05:28,  2.09it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# /home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  94%|█████████▎| 9351/10000 [1:35:50<03:31,  3.07it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  94%|█████████▍| 9392/10000 [1:36:13<04:52,  2.08it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  94%|█████████▍| 9421/10000 [1:36:29<03:14,  2.98it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  94%|█████████▍| 9427/10000 [1:36:30<02:10,  4.38it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  94%|█████████▍| 9434/10000 [1:36:33<03:19,  2.84it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  95%|█████████▍| 9483/10000 [1:36:53<07:07,  1.21it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  95%|█████████▍| 9489/10000 [1:36:55<04:36,  1.85it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  95%|█████████▌| 9512/10000 [1:37:02<02:46,  2.94it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  96%|█████████▌| 9557/10000 [1:37:31<03:27,  2.13it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  97%|█████████▋| 9671/10000 [1:38:26<02:55,  1.88it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  97%|█████████▋| 9673/10000 [1:38:31<06:42,  1.23s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  97%|█████████▋| 9746/10000 [1:39:16<01:38,  2.57it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  98%|█████████▊| 9787/10000 [1:39:41<01:51,  1.91it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  99%|█████████▊| 9857/10000 [1:40:23<00:54,  2.62it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  99%|█████████▉| 9895/10000 [1:40:40<00:40,  2.60it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
#  99%|█████████▉| 9914/10000 [1:40:56<01:36,  1.12s/it]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# 100%|█████████▉| 9959/10000 [1:41:25<00:21,  1.93it/s]/home/opriebe/dev/HapASeg/hapaseg/NB_coverage_MCMC.py:380: RuntimeWarning: invalid value encountered in log
#   return np.log(2 * np.pi) - (np.log(np.linalg.det(-H1) * np.linalg.det(-H2))) / 2
# 100%|██████████| 10000/10000 [1:41:46<00:00,  1.64it/s]

# %%
plt.plot(range(len(nb_mcmc.ll_iter)), nb_mcmc.ll_iter)

# %%
residuals = []
for clust in nb_mcmc.clusters:
    residuals.append(np.exp(np.log(clust.r.flatten()) - (clust.mu.flatten()) - (clust.C@clust.beta).flatten()))

# %%
fig , axs = plt.subplots(5,4, figsize = (25,18), sharey=True)
ax_lst = axs.flatten()
for targ, cov_idx in Cov_overlap.groupby("cluster_assgn").indices.items():
    ax_lst[targ].scatter(np.r_[:len(residuals[targ])], residuals[targ])
    ax_lst[targ].set_title('cluster {} residuals'.format(targ))
    if len(nb_mcmc.F_samples[0][targ]) > 0:
        hist = np.array(nb_mcmc.F_samples[0][targ]).reshape(-1,2)
        for j, r in enumerate(hist):
            ax_lst[targ].add_patch(matplotlib.patches.Rectangle((r[0],0), r[1]-r[0], 2.3, fill=True, alpha=0.3, color = colors[j % 10]))

# %%
fig , axs = plt.subplots(5,4, figsize = (25,18), sharey=True)
ax_lst = axs.flatten()
samp = 3
for targ, cov_idx in Cov_overlap.groupby("cluster_assgn").indices.items():
    ax_lst[targ].scatter(np.r_[:len(residuals[targ])], residuals[targ])
    ax_lst[targ].set_title('cluster {} residuals'.format(targ))
    if len(nb_mcmc.F_samples[samp][targ]) > 0:
        hist = np.array(nb_mcmc.F_samples[samp][targ]).reshape(-1,2)
        for j, r in enumerate(hist):
            ax_lst[targ].add_patch(matplotlib.patches.Rectangle((r[0],0), r[1]-r[0], 2.3, fill=True, alpha=0.3, color = colors[j % 10]))

# %%
fig , axs = plt.subplots(8,5, figsize = (25,25), sharey=True)
ax_lst = axs.flatten()
clust = 12
for samp in range(len(nb_mcmc.F_samples)):
    ax_lst[samp].scatter(np.r_[:len(residuals[clust])], residuals[clust])
    ax_lst[samp].set_title('sample {} residuals'.format(samp))
    if len(nb_mcmc.F_samples[samp][clust]) > 0:
        hist = np.array(nb_mcmc.F_samples[samp][clust]).reshape(-1,2)
        for j, r in enumerate(hist):
            ax_lst[samp].add_patch(matplotlib.patches.Rectangle((r[0],0), r[1]-r[0], 2.3, fill=True, alpha=0.3, color = colors[j % 10]))

# %%
tst = [nb_mcmc.clusters[0].r, nb_mcmc.clusters[1].r, nb_mcmc.clusters[2].r]

# %%
values = map(lambda k, v: if k != 1: v, d.keys())
# Out:
#   File "<ipython-input-124-f10d044c6147>", line 1
#     values = map(lambda k, v: if k != 1: v, d.keys())
#                               ^
# SyntaxError: invalid syntax

# %%
tst_dict = sc.SortedDict({0:1, 1:2})

# %%
[value for (key,value) in tst_dict.items() if key != 0]
# Out:
# [2]

# %%
np.concatenate([nb_mcmc.clusters[0].C, nb_mcmc.clusters[1].C]).shape
# Out:
# (1286, 3)

# %%
residuals[12][:20]
# Out:
# array([0.66272526, 0.79464723, 1.24792166, 1.42017148, 1.16587883,
#        1.09174663, 1.2718178 , 1.39691487, 0.90258578, 0.79578544,
#        0.82468784, 0.58520123, 0.87400298, 0.75578799, 0.89112182,
#        1.41090583, 0.99345844, 1.1960743 , 0.81727044, 0.88691078])

# %%
residuals[12][12:20]
# Out:
# array([0.87400298, 0.75578799, 0.89112182, 1.41090583, 0.99345844,
#        1.1960743 , 0.81727044, 0.88691078])

# %%
nb_mcmc.clusters[12].stats_optimizer((0,2))
# Out:
# (-0.3165120303452187, 8.189200911456094)

# %%
nb_mcmc.clusters[12].stats_optimizer((2,25))
# Out:
# (0.09177083608106092, 2.8746992242519487)

# %%
nb_mcmc.clusters[12].calc_pk((0,16), debug=True)
# Out:
# (array([-1459.54498228, -1439.18558751, -1439.34121851, -1439.32619245,
#         -1439.2444053 , -1438.77856908, -1437.54701365, -1437.89883224,
#         -1438.5058212 , -1438.82611799, -1439.39463466, -1439.47074767,
#         -1439.12275672]),
#  3,
#  -1439.185587511988,
#  0.05006798725737678,
#  (-0.10340163759204331, 0.029305485518938964),
#  (2.7137773306054647, 2.747470973023267),
#  (array([[-4.12745226e+01, -5.47466072e-09],
#          [-5.47466072e-09, -2.91073701e+02]]),
#   array([[-1.86533148e+02, -2.88751778e-08],
#          [-2.88751778e-08, -1.35856081e+03]])))

# %%
nb_mcmc.clusters[12].ll_nbinom(nb_mcmc.clusters[12].r[:2], nb_mcmc.clusters[12].mu, nb_mcmc.clusters[12].C[:2], nb_mcmc.clusters[12].beta, -0.31, 3.5)
# Out:
# -19.806546469271694

# %%
nb_mcmc.clusters[12].ll_nbinom(nb_mcmc.clusters[12].r[:2], nb_mcmc.clusters[12].mu, nb_mcmc.clusters[12].C[:2], nb_mcmc.clusters[12].beta, -0.31, 8.1)
# Out:
# -40.081240409516795

# %%
eps = np.r_[-2:12:0.1]
res = []
for ep in eps:
    res.append(nb_mcmc.clusters[12].ll_nbinom(nb_mcmc.clusters[12].r[:2], nb_mcmc.clusters[12].mu, nb_mcmc.clusters[12].C[:2], nb_mcmc.clusters[12].beta, -0.3, ep))
plt.plot(eps, res)
plt.axvline(8.1)

# %%
from statsmodels.discrete.discrete_model import NegativeBinomial as statsNB

# %%
def stats_optimizer(self, ind, ret_hess=False):
    endog = np.exp(np.log(self.r[ind[0]:ind[1]].flatten()) - (self.C[ind[0]:ind[1]] @ self.beta).flatten())
    exog = np.ones(self.r[ind[0]:ind[1]].shape[0])
    exposure = np.ones(self.r[ind[0]:ind[1]].shape[0]) * np.exp(self.mu)
    sNB = statsNB(endog, exog, exposure=exposure)
    res = sNB.fit(method='bfgs',disp=0)

    if ret_hess:
        return res.params[0], -np.log(res.params[1]), sNB.hessian(res.params)
    else:
        return res.params[0], -np.log(res.params[1])

# %%
stats_optimizer(nb_mcmc.clusters[12],(0,2))
# Out:
# (-0.3165120303452187, 8.189200911456094)

# %%
overlap_tst = Cov_overlap.copy()

# %%
overlap_tst['segment_ID'] = 0

# %%
seg_id_col = overlap_tst.columns.get_loc('segment_ID')

# %%
#convert Cov_MCMC object into segment objects to be used by cov_DP

global_seg_counter = 0
for i, clust in enumerate(nb_mcmc.clusters):
    pi_argmax = Pi.argmax(1)
    og_positions = np.where(pi_argmax == i)[0]
    seg_intervals = np.array(clust.F).reshape(-1,2)
    for st, en in seg_intervals:
        seg_ind = og_positions[st:en]
        overlap_tst.iloc[seg_ind, seg_id_col] = global_seg_counter
        global_seg_counter += 1

# %%
overlap_tst.to_pickle('./cov_MCMC_df')

# %%
np.save('./beta_save', nb_mcmc.beta)
